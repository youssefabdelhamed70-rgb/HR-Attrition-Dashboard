# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns  
import scipy as sp
#importing some libraries

# %%
df = pd.read_csv('D:\machinfy data analisys\Final project\WA_Fn-UseC_-HR-Employee-Attrition (2) (1).csv')
#reading the file

# %%
df = df.drop('Over18',axis=1)
df = df.drop('StandardHours' , axis=1)
df = df.drop('EmployeeCount' , axis=1)
#drop some columns that we don't need in data

# %%
df['EmployeeNumber'] = df['EmployeeNumber'].astype('object')
df = df.rename(columns={'EmployeeNumber':'EmployeeID'})
#changing Data Type to column and rename it to ID

# %%
df.info()
#check the data before exporting
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeID                1470 non-null   object
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   object
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
# ...

# %%
df.to_csv('D:\machinfy data analisys\Final project\clean data.csv',index=False)
#exporting data to CSV
